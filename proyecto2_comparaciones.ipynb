# %%
from PIL import Image
from IPython.display import display

def display_img(ruta_imagen):
    scale = 1
    imagen = Image.open(ruta_imagen)
    nuevo_ancho = int(imagen.width * scale)
    nuevo_alto = int(imagen.height * scale)
    imagen_redimensionada = imagen.resize((nuevo_ancho, nuevo_alto))
    display(imagen_redimensionada)

# %% [markdown]
# # Parte 1: MLP

# %% [markdown]
# ## Arquitecturas

# %%
display_img('results/MLP_arquitectura.jpeg')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# ## Resultados

# %%
display_img('results/MLP_comparacion.jpeg')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# # ◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎◼︎

# %% [markdown]
# # Parte 2: CNN

# %% [markdown]
# ## Arquitecturas

# %%
display_img('results/CNN_arquitectura.jpeg')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# ## Resultados

# %%
display_img('results/CNN_comparacion.jpeg')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# ## Conclusiones
#
# ## ¿Qué ventajas tiene utilizar un feature extractor? referirse a las métricas y tiempos
#
# ## ¿Qué modelo se entrena más rápido?
#
# ## ¿Cuáles secciones de la imagen son las más importantes para la elección?
#
# ## ¿Cuál fue el mejor modelo?
